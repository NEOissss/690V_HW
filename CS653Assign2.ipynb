# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import column, row
from bokeh.models import ColumnDataSource, Circle, Line, HoverTool, Slider
import analyze

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3c24053e-c3dc-45cf-a460-d131ec4f4b60">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### For Experiment 1

# %%
def exp1_draw(b, c, d, e):
    tcp_list = ["Tahoe", "Reno", "Newreno", "Vegas"]
    color = ["green","blue","yellow","red"] 
    dash = ['dashed','dotted','dotdash','dashdot']
    title = "CBR:"+str(b+1)+"-"+str(c + 11)+","+d+","+e
    plot1 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'latency(s)')
    plot2 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'throughput(bits)')
    plot3 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'drop rate')
    plot4 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'SEQ Num')
    plot5 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'CWND')

    for i in range(len(tcp_list)):
        a = tcp_list[i]
        #b = -1
        #c = 1.0
        #d = "8Mb"
        #e = "L"
        filename = "DropTail"+"_"+"10Mb"+"_"+e+"_"+d+"_"+str(b+1)+"_"+str(c + 11)+"_"+"L"+"_"+a+"_"+"1"+"_"+"11"+".tr"
        re = analyze.analyze("exp1/"+filename,0.5)
        #print re
        plot1.line(re["datapoints"],re["N1-N4"]["latency"],line_width=2,color=color[i],legend=tcp_list[i],line_alpha=0.75)
        plot2.line(re["datapoints"],re["N1-N4"]["throughput"],line_width=2,color=color[i],legend=tcp_list[i],line_alpha=0.75)
        plot3.line(re["datapoints"],re["N1-N4"]["dropRate"],line_width=2,color=color[i],legend=tcp_list[i],line_alpha=0.75)
        plot4.line(re["datapoints"],re["N1-N4"]["sequences"],line_width=2,color=color[i],legend=tcp_list[i],line_alpha=0.75)
        plot5.line(re["datapoints"],re["N1-N4"]["windows"],line_width=2,color=color[i],legend=tcp_list[i],line_alpha=0.75)
        
    plot1.legend.location = "bottom_right"
    plot2.legend.location = "bottom_right"
    plot3.legend.location = "top_right"
    plot4.legend.location = "top_left"
    plot5.legend.location = "top_left"
    show(row(plot1,plot2,plot3,plot4,plot5))

# %%
# Parameters:
# exp1_draw(b, c, d, e)
# b >> gap_start = [-1, 0.1, 1.0, 4.0]
# c >> gap_stop = [1.0, -0.1, -1.0, -4.0]
# d >> cbr_bw = ["1Mb", "2Mb", "4Mb", "8Mb"]
# e >> cbr_dir = ["L", "R"]

# %%
exp1_draw(1.0,-1.0,"1Mb","L")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# ...

# %%
exp1_draw(1.0,-1.0,"4Mb","L")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# ...

# %%
exp1_draw(4.0,-4.0,"4Mb","L")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# ...

# %%
exp1_draw(1.0,-1.0,"8Mb","L")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# ...

# %%
exp1_draw(4.0,-4.0,"8Mb","L")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# ...

# %%
exp1_draw(1.0,-1.0,"8Mb","R")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# ...

# %% [markdown]
# ### For Experiment 2

# %%
def exp2_draw(i, c, d, e, f):
    tcp1_list = ["Reno", "Reno", "Vegas", "Vegas"]
    tcp2_list = ["Reno", "Newreno", "Vegas", "Newreno"]
    color = ["blue","red"] 
    title = "CBR:"+f+","+tcp1_list[i]+"&"+tcp2_list[i]+","+d+"&"+e
    plot1 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'latency(s)')
    plot2 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'throughput(bits)')
    plot3 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'drop rate')
    plot4 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'SEQ Num')
    plot5 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'CWND')
    
    a = tcp1_list[i]
    b = tcp2_list[i]
    #c = -1
    #d = 1.0
    #e = "8Mb"
    #f = "L"
    filename = "DropTail"+"_"+"10Mb"+"_"+"L"+"_"+f+"_"+"12"+"_"+"22"+"_"+d+"_"+a+"_"+"10"+"_"+"25"+"_"+e+"_"+b+"_"+str(c+10)+"_"+"35"+".tr"
    re = analyze.analyze("exp2/"+filename,0.5)
    #print re
    plot1.line(re["datapoints"],re["N1-N4"]["latency"],line_width=2,color=color[0],legend=tcp1_list[i]+"("+d+")",line_alpha=0.6)
    plot1.line(re["datapoints"],re["N5-N6"]["latency"],line_width=2,color=color[1],legend=tcp2_list[i]+"("+e+")",line_alpha=0.6)
    plot2.line(re["datapoints"],re["N1-N4"]["throughput"],line_width=2,color=color[0],legend=tcp1_list[i]+"("+d+")",line_alpha=0.6)
    plot2.line(re["datapoints"],re["N5-N6"]["throughput"],line_width=2,color=color[1],legend=tcp2_list[i]+"("+e+")",line_alpha=0.6)
    plot3.line(re["datapoints"],re["N1-N4"]["dropRate"],line_width=2,color=color[0],legend=tcp1_list[i]+"("+d+")",line_alpha=0.6)
    plot3.line(re["datapoints"],re["N5-N6"]["dropRate"],line_width=2,color=color[1],legend=tcp2_list[i]+"("+e+")",line_alpha=0.6)
    plot4.line(re["datapoints"],re["N1-N4"]["sequences"],line_width=2,color=color[0],legend=tcp1_list[i]+"("+d+")",line_alpha=0.75)
    plot4.line(re["datapoints"],re["N5-N6"]["sequences"],line_width=2,color=color[1],legend=tcp2_list[i]+"("+e+")",line_alpha=0.75)
    plot5.line(re["datapoints"],re["N1-N4"]["windows"],line_width=2,color=color[0],legend=tcp1_list[i]+"("+d+")",line_alpha=0.75)
    plot5.line(re["datapoints"],re["N5-N6"]["windows"],line_width=2,color=color[1],legend=tcp2_list[i]+"("+e+")",line_alpha=0.75)

   
    plot1.legend.location = "bottom_right"
    plot2.legend.location = "bottom_right"
    plot3.legend.location = "bottom_right"
    plot4.legend.location = "top_left"
    plot5.legend.location = "top_left"
    show(row(plot1,plot2,plot3,plot4,plot5))

# %%
# Parameters: 
# exp2_draw(c, d, e, f)
# i >> [0, 1, 2, 3]
# c >> gap_start = [-10.0, -4.0, -1.0, 0.0, 1.0, 4.0, 10.0]
# d >> ftp1_dir = ["L", "R"]
# e >> ftp2_dir = ["L", "R"]
# f >> cbr_bw = ["4Mb", "6Mb", "8Mb", "10Mb"]

# %%
exp2_draw(0, -4.0, "L", "L", "4Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1e626e81-17a3-43ab-a8e3-ec81bc950beb"></div>
# </div>

# %%
exp2_draw(0, 4.0, "L", "L", "4Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="0190e405-07a8-4f52-8df8-db5f415ec465"></div>
# </div>

# %%
exp2_draw(0, -4.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6d1671bc-6fb5-4343-b524-be9775ab4319"></div>
# </div>

# %%
exp2_draw(0, 0.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="793b1e24-16a3-43af-9fd3-b4b540abac38"></div>
# </div>

# %%
exp2_draw(0, 4.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b4a2691f-5e71-4962-ae4c-0f97726f7404"></div>
# </div>

# %%
exp2_draw(0, 4.0, "L", "L", "10Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 54)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="97050328-23b8-4031-9051-f5123e457991"></div>
# </div>

# %%
exp2_draw(0, 4.0, "R", "R", "10Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="155aa4d9-b33e-4baf-ab6d-18f7cfd89e4d"></div>
# </div>

# %%
exp2_draw(0, 4.0, "L", "R", "10Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 54)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ae04a6af-e997-445b-83e2-c2cf6a605ae2"></div>
# </div>

# %%
exp2_draw(0, 4.0, "R", "L", "10Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8946d80b-9394-4c05-b2df-06605f51bb44"></div>
# </div>

# %%
exp2_draw(1, -4.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="592c1db6-3229-499d-997c-86fe79e98a81"></div>
# </div>

# %%
exp2_draw(1, 0.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d9a27d91-47ce-4fc4-b81c-407e510580db"></div>
# </div>

# %%
exp2_draw(1, 4.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="53be6f57-34af-4021-9360-7d7bddf5928d"></div>
# </div>

# %%
exp2_draw(2, -4.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="2e41140a-8b23-4824-a9e2-5851e641fbc4"></div>
# </div>

# %%
exp2_draw(2, 0.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="312a6c2d-7116-4730-86aa-70148b0058bf"></div>
# </div>

# %%
exp2_draw(2, 4.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="28ccd951-8f59-4bef-b793-c0c2f3643285"></div>
# </div>

# %%
exp2_draw(3, -4.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a708d484-616e-402a-8867-5ff9e7b850c6"></div>
# </div>

# %%
exp2_draw(3, 0.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="cd6b7d27-4171-4167-b907-aa959853f04d"></div>
# </div>

# %%
exp2_draw(3, 4.0, "L", "L", "8Mb")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 52)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 70), ('y', 71)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8105d06f-bef5-4eba-9cf8-ceb7795e4e27"></div>
# </div>

# %% [markdown]
# ### For Experiment 3

# %%
def exp3_draw(a, c):
    que_list = ["DropTail", "RED"]
    color = ["blue","red"] 
    title = a+","+c
    plot1 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'latency(s)')
    plot2 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'throughput(bits)')
    plot3 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'drop rate')
    plot4 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'SEQ Num')
    plot5 = figure(title = title, x_axis_label = 'time(s)', y_axis_label = 'CWND')
    
    for i in range(len(que_list)):
        #a = "Reno"
        b = que_list[i]
        #c = 1.0
        filename = b+"_"+"10Mb"+"_"+"L"+"_"+"8Mb"+"_"+"0"+"_"+"10"+"_"+c+"_"+a+"_"+"1"+"_"+"11"+".tr"
        re = analyze.analyze("exp3/"+filename,0.5)
        #print re
        plot1.line(re["datapoints"],re["N1-N4"]["latency"],line_width=2,color=color[i],legend=que_list[i],line_alpha=0.8)
        plot2.line(re["datapoints"],re["N1-N4"]["throughput"],line_width=2,color=color[i],legend=que_list[i],line_alpha=0.8)
        plot3.line(re["datapoints"],re["N1-N4"]["dropRate"],line_width=2,color=color[i],legend=que_list[i],line_alpha=0.8)
        plot4.line(re["datapoints"],re["N1-N4"]["sequences"],line_width=2,color=color[i],legend=que_list[i],line_alpha=0.75)
        plot5.line(re["datapoints"],re["N1-N4"]["windows"],line_width=2,color=color[i],legend=que_list[i],line_alpha=0.75)

    plot1.legend.location = "bottom_right"
    plot2.legend.location = "bottom_right"
    plot3.legend.location = "bottom_right"
    plot4.legend.location = "top_left"
    plot5.legend.location = "top_left"
    show(row(plot1,plot2,plot3,plot4,plot5))

# %%
# Parameters:
# exp3_draw(a, c)
# a >> tcp_list = ["Reno", "Sack1"]
# c >> ftp_dir = ["L", "R"]

# %%
exp3_draw("Reno", "L")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f8d4489c-5816-48a9-9b8f-bb658a2497c8"></div>
# </div>

# %%
exp3_draw("Sack1", "L")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7a865b14-1d5f-4d68-866a-7cdafa51d92b"></div>
# </div>

# %%
exp3_draw("Reno", "R")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="14c067f7-c66e-4465-ab5a-07dee4674624"></div>
# </div>

# %%
exp3_draw("Sack1", "R")
# Out:
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# /Users/neo/Documents/Codes/690V/lib/python2.7/site-packages/bokeh/models/sources.py:137: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 22), ('y', 23)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b2c67e2d-252b-40c2-bb84-9618824d206c"></div>
# </div>
